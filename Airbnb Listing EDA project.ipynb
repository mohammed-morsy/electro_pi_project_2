# %% [markdown]
# ### Project Description:
# This project focuses on performing an exploratory data analysis (EDA) of Airbnb listings within Albany, New York, United States. The goal is to examine various factors such as price, availability, location, and property type to uncover the underlying trends and patterns that influence the demand for Airbnb listings. Through this analysis, we aim to provide a comprehensive overview of the Airbnb market in Albany city, helping stakeholders to make informed decisions.
#
# ### Objectives:
# - Analyze key factors that influence the demand for Airbnb listings in the Albany city(Droping any observation except Albany, NY in host_location column.), including but not limited to price, availability, location, and property type.
# - Perform thorough data cleaning to prepare the dataset for in-depth analysis, ensuring the removal of outliers and handling of missing values.
# - Utilize advanced data visualization techniques to illustrate trends and patterns in the data, making it easier to identify key insights.
# - Conduct statistical analysis to substantiate the findings and insights derived from the data.
#
# ### Tools:
# - Employ Python and Jupyter Notebook as the primary tools for conducting the analysis and visualization, leveraging libraries such as Pandas, NumPy, Matplotlib, and Seaborn.
#
# ### Steps:
# - Data Cleaning: The data must be efficiently cleaned to remove inaccuracies and prepare it for analysis. This includes handling missing values, removing outliers, and ensuring the data is consistent.
# - Data Analysis: should thoroughly examine the impact of various factors like price, availability, location, and property type on the demand for Airbnb listings.
# - Data Visualization giving insights for demand.: should be developed to clearly depict the trends and patterns identified in the analysis. These visualizations should be insightful, making it easy to grasp the dynamics of the Airbnb market in the Albany city.
# - Statistical analysis : to validate the trends and patterns observed, providing a solid foundation for the conclusions drawn from the data.
# - Findings : to explained a business plan based on the insights gained from the analysis.
#
# ### The data was obtained through this link:
# https://insideairbnb.com/get-the-data

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import functools

# %% [markdown]
# ### Load Airbnb Dataset and file for feature describtion.

# %%
#f_d = feature describtion.
df = pd.read_csv('/Users/drmorsy/Electro_pi/Exploratory Data Analysis/listings.csv')
v_d = pd.read_csv('/Users/drmorsy/Electro_pi/Exploratory Data Analysis/Data_variables_describtion.csv', low_memory=False)
df.head()
# Out:
#          id                            listing_url     scrape_id last_scraped  \
# 0  25549565  https://www.airbnb.com/rooms/25549565  2.024030e+13   11/03/2024
# 1  10768745  https://www.airbnb.com/rooms/10768745  2.024030e+13   11/03/2024
# 2  28722270  https://www.airbnb.com/rooms/28722270  2.024030e+13   11/03/2024
# 3   9005989   https://www.airbnb.com/rooms/9005989  2.024030e+13   11/03/2024
# 4  28868857  https://www.airbnb.com/rooms/28868857  2.024030e+13   11/03/2024
#
#         source                                               name  \
# 0  city scrape     Quiet and Pretty in the Heart of Center Square
# 1  city scrape          Alb hospital area studio bath wifi. (Red)
# 2  city scrape             ✍Historic Loft Suite @ Downtown Albany
# 3  city scrape     Studio in The heart of Center SQ, in Albany NY
# 4  city scrape  ⭐Cozy Garden Suite Full Amenities @Downtown Al...
#
#                                          description  \
# 0  Private entrance to garden level suite in a hi...
# 1  Spacious warm studio in 1840 house close to ho...
# 2  BOOK this attic loft in a renovated historic 2...
# 3  (21 years of age or older ONLY) NON- SMOKING.....
# 4  BOOK our affordable basement-level suite in th...
#
#                                neighborhood_overview  \
# 0  This neighorhood is a village of all kinds of ...
# 1                                                NaN
# 2  + 92 Walkscore<br />+ 5-minute walk to MVP Are...
# 3  There are many shops, restaurants, bars, museu...
# 4  + 92 Walkscore<br />+ 5-minute walk to MVP Are...
#
#                                          picture_url   host_id  ...  \
# 0  https://a0.muscache.com/pictures/662f1c8d-3841...   9666970  ...
# 1  https://a0.muscache.com/pictures/8694ad4b-98f9...   5691268  ...
# 2  https://a0.muscache.com/pictures/798e28e4-70ec...  44434571  ...
# 3  https://a0.muscache.com/pictures/d242a77e-437c...  17766924  ...
# 4  https://a0.muscache.com/pictures/hosting/Hosti...  44434571  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.95                   4.92                4.91
# 1                        4.87                   4.92                4.90
# 2                        4.91                   4.74                4.82
# 3                        4.92                   4.87                4.78
# 4                        4.89                   4.63                4.69
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              2
# 2     NaN                f                              6
# 3     NaN                f                              1
# 4     NaN                f                              6
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           2
# 2                                           6
# 3                                           1
# 4                                           6
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0             11.08
# 1                                           0              6.40
# 2                                           0              9.56
# 3                                           0              6.27
# 4                                           0              8.48
#
# [5 rows x 75 columns]

# %%
v_d.drop('Calculated', axis=1, inplace=True)
#f_d = feature description 
def f_d(feature, data=v_d, column='Field'):
    '''
    This function give us some insight about certain feature.
    feature: What I would like to gain insights into.
    Data: The file contains information about each feature, the default is v_d.
    column: The column contains the feature names, and the default column is Field.
    '''
    return data[data[column]==feature]

# %% [markdown]
# # About the Dataset
# Airbnb is:an online marketplace that connects people who want to rent out their homes with people looking  for accommodations in specific locales. The idea behind Airbnb is simple: matching local people with a spare room or entire home to rent to others who are visiting the area.
# 1. This Airbnb dataset contains 404 observations from Albany, New York city with 75 columns of data.
# 2. The data includes both categorical and numerical values, providing a diverse range information about the listings.
# 3. This data may be useful for analysing trends and patterns the Airbnb market in Albany, New York, United States and also gain insights into the preferences and behavior of Airbnb users in the area.
# 4. This data has been updated until March 10, 2024.
# 5. If you want to know the purpose of the feature, just run this function; f_d(data, column, feature).

# %%
df.shape
# Out:
# (404, 75)

# %%
df.dtypes.value_counts()
# Out:
# object     34
# int64      22
# float64    19
# Name: count, dtype: int64

# %%
f_d('price')
# Out:
#     Field      Type                    Description Reference  Unnamed: 5
# 40  price  currency  daily price in local currency       NaN         NaN

# %% [markdown]
# ### Data Exploration and Data Cleaning

# %%
#basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            404 non-null    int64
#  1   listing_url                                   404 non-null    object
#  2   scrape_id                                     404 non-null    float64
#  3   last_scraped                                  404 non-null    object
#  4   source                                        404 non-null    object
#  5   name                                          404 non-null    object
#  6   description                                   392 non-null    object
#  7   neighborhood_overview                         245 non-null    object
#  8   picture_url                                   404 non-null    object
#  9   host_id                                       404 non-null    int64
#  10  host_url                                      404 non-null    object
#  11  host_name                                     404 non-null    object
#  12  host_since                                    404 non-null    object
#  13  host_location                                 313 non-null    object
#  14  host_about                                    214 non-null    object
#  15  host_response_time                            375 non-null    object
#  16  host_response_rate                            375 non-null    object
#  17  host_acceptance_rate                          389 non-null    object
#  18  host_is_superhost                             403 non-null    object
#  19  host_thumbnail_url                            404 non-null    object
#  20  host_picture_url                              404 non-null    object
#  21  host_neighbourhood                            321 non-null    object
#  22  host_listings_count                           404 non-null    int64
#  23  host_total_listings_count                     404 non-null    int64
#  24  host_verifications                            404 non-null    object
#  25  host_has_profile_pic                          404 non-null    object
#  26  host_identity_verified                        404 non-null    object
#  27  neighbourhood                                 245 non-null    object
#  28  neighbourhood_cleansed                        404 non-null    object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      404 non-null    float64
#  31  longitude                                     404 non-null    float64
#  32  property_type                                 404 non-null    object
#  33  room_type                                     404 non-null    object
#  34  accommodates                                  404 non-null    int64
#  35  bathrooms                                     350 non-null    float64
#  36  bathrooms_text                                404 non-null    object
#  37  bedrooms                                      400 non-null    float64
#  38  beds                                          350 non-null    float64
#  39  amenities                                     404 non-null    object
#  40  price                                         350 non-null    object
#  41  minimum_nights                                404 non-null    int64
#  42  maximum_nights                                404 non-null    int64
#  43  minimum_minimum_nights                        404 non-null    int64
#  44  maximum_minimum_nights                        404 non-null    int64
#  45  minimum_maximum_nights                        404 non-null    int64
#  46  maximum_maximum_nights                        404 non-null    int64
#  47  minimum_nights_avg_ntm                        404 non-null    float64
#  48  maximum_nights_avg_ntm                        404 non-null    float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              399 non-null    object
#  51  availability_30                               404 non-null    int64
#  52  availability_60                               404 non-null    int64
#  53  availability_90                               404 non-null    int64
#  54  availability_365                              404 non-null    int64
#  55  calendar_last_scraped                         404 non-null    object
#  56  number_of_reviews                             404 non-null    int64
#  57  number_of_reviews_ltm                         404 non-null    int64
#  58  number_of_reviews_l30d                        404 non-null    int64
#  59  first_review                                  362 non-null    object
#  60  last_review                                   362 non-null    object
#  61  review_scores_rating                          362 non-null    float64
#  62  review_scores_accuracy                        362 non-null    float64
#  63  review_scores_cleanliness                     362 non-null    float64
#  64  review_scores_checkin                         362 non-null    float64
#  65  review_scores_communication                   362 non-null    float64
#  66  review_scores_location                        362 non-null    float64
#  67  review_scores_value                           362 non-null    float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              404 non-null    object
#  70  calculated_host_listings_count                404 non-null    int64
#  71  calculated_host_listings_count_entire_homes   404 non-null    int64
#  72  calculated_host_listings_count_private_rooms  404 non-null    int64
#  73  calculated_host_listings_count_shared_rooms   404 non-null    int64
#  74  reviews_per_month                             362 non-null    float64
# dtypes: float64(19), int64(22), object(34)
# memory usage: 236.8+ KB

# %%
df.head(5).T[:25]
# Out:
#                                                                            0  \
# id                                                                  25549565
# listing_url                            https://www.airbnb.com/rooms/25549565
# scrape_id                                                   20240300000000.0
# last_scraped                                                      11/03/2024
# source                                                           city scrape
# name                          Quiet and Pretty in the Heart of Center Square
# description                Private entrance to garden level suite in a hi...
# neighborhood_overview      This neighorhood is a village of all kinds of ...
# picture_url                https://a0.muscache.com/pictures/662f1c8d-3841...
# host_id                                                              9666970
# host_url                           https://www.airbnb.com/users/show/9666970
# host_name                                                              Janet
# host_since                                                        27/10/2013
# host_location                                                     Albany, NY
# host_about                 Born in Philly, long-term expat in China, seri...
# host_response_time                                        within a few hours
# host_response_rate                                                       96%
# host_acceptance_rate                                                     91%
# host_is_superhost                                                          f
# host_thumbnail_url         https://a0.muscache.com/im/pictures/user/34f77...
# host_picture_url           https://a0.muscache.com/im/pictures/user/34f77...
# host_neighbourhood                                                       NaN
# host_listings_count                                                        1
# host_total_listings_count                                                  1
# host_verifications                                        ['email', 'phone']
#
#                                                                            1  \
# id                                                                  10768745
# listing_url                            https://www.airbnb.com/rooms/10768745
# scrape_id                                                   20240300000000.0
# last_scraped                                                      11/03/2024
# source                                                           city scrape
# name                               Alb hospital area studio bath wifi. (Red)
# description                Spacious warm studio in 1840 house close to ho...
# neighborhood_overview                                                    NaN
# picture_url                https://a0.muscache.com/pictures/8694ad4b-98f9...
# host_id                                                              5691268
# host_url                           https://www.airbnb.com/users/show/5691268
# host_name                                                          Elizabeth
# host_since                                                        30/03/2013
# host_location                                                     Albany, NY
# host_about                 I'm Irish living in Albany NY.  I have 3 grown...
# host_response_time                                            within an hour
# host_response_rate                                                      100%
# host_acceptance_rate                                                     88%
# host_is_superhost                                                          f
# host_thumbnail_url         https://a0.muscache.com/im/pictures/user/d34e6...
# host_picture_url           https://a0.muscache.com/im/pictures/user/d34e6...
# host_neighbourhood                                                       NaN
# host_listings_count                                                        2
# host_total_listings_count                                                  3
# host_verifications                                        ['email', 'phone']
#
#                                                                            2  \
# id                                                                  28722270
# listing_url                            https://www.airbnb.com/rooms/28722270
# scrape_id                                                   20240300000000.0
# last_scraped                                                      11/03/2024
# source                                                           city scrape
# name                                  ✍Historic Loft Suite @ Downtown Albany
# description                BOOK this attic loft in a renovated historic 2...
# neighborhood_overview      + 92 Walkscore<br />+ 5-minute walk to MVP Are...
# picture_url                https://a0.muscache.com/pictures/798e28e4-70ec...
# host_id                                                             44434571
# host_url                          https://www.airbnb.com/users/show/44434571
# host_name                                                               Earl
# host_since                                                        17/09/2015
# host_location                                                            NaN
# host_about                 I grew up in Cebu, Philippines and moved to Ne...
# host_response_time                                            within an hour
# host_response_rate                                                      100%
# host_acceptance_rate                                                    100%
# host_is_superhost                                                          f
# host_thumbnail_url         https://a0.muscache.com/im/pictures/user/6bc9c...
# host_picture_url           https://a0.muscache.com/im/pictures/user/6bc9c...
# host_neighbourhood                                                  Pastures
# host_listings_count                                                        7
# host_total_listings_count                                                  7
# host_verifications                                        ['email', 'phone']
#
#                                                                            3  \
# id                                                                   9005989
# listing_url                             https://www.airbnb.com/rooms/9005989
# scrape_id                                                   20240300000000.0
# last_scraped                                                      11/03/2024
# source                                                           city scrape
# name                          Studio in The heart of Center SQ, in Albany NY
# description                (21 years of age or older ONLY) NON- SMOKING.....
# neighborhood_overview      There are many shops, restaurants, bars, museu...
# picture_url                https://a0.muscache.com/pictures/d242a77e-437c...
# host_id                                                             17766924
# host_url                          https://www.airbnb.com/users/show/17766924
# host_name                                                              Sugey
# host_since                                                        07/07/2014
# host_location                                                     Albany, NY
# host_about                                                               NaN
# host_response_time                                            within an hour
# host_response_rate                                                      100%
# host_acceptance_rate                                                    100%
# host_is_superhost                                                          f
# host_thumbnail_url         https://a0.muscache.com/im/pictures/user/ae311...
# host_picture_url           https://a0.muscache.com/im/pictures/user/ae311...
# host_neighbourhood                                                       NaN
# host_listings_count                                                        1
# host_total_listings_count                                                  1
# host_verifications                                        ['email', 'phone']
#
#                                                                            4
# id                                                                  28868857
# listing_url                            https://www.airbnb.com/rooms/28868857
# scrape_id                                                   20240300000000.0
# last_scraped                                                      11/03/2024
# source                                                           city scrape
# name                       ⭐Cozy Garden Suite Full Amenities @Downtown Al...
# description                BOOK our affordable basement-level suite in th...
# neighborhood_overview      + 92 Walkscore<br />+ 5-minute walk to MVP Are...
# picture_url                https://a0.muscache.com/pictures/hosting/Hosti...
# host_id                                                             44434571
# host_url                          https://www.airbnb.com/users/show/44434571
# host_name                                                               Earl
# host_since                                                        17/09/2015
# host_location                                                            NaN
# host_about                 I grew up in Cebu, Philippines and moved to Ne...
# host_response_time                                            within an hour
# host_response_rate                                                      100%
# host_acceptance_rate                                                    100%
# host_is_superhost                                                          f
# host_thumbnail_url         https://a0.muscache.com/im/pictures/user/6bc9c...
# host_picture_url           https://a0.muscache.com/im/pictures/user/6bc9c...
# host_neighbourhood                                                  Pastures
# host_listings_count                                                        7
# host_total_listings_count                                                  7
# host_verifications                                        ['email', 'phone']

# %%
df.head(5).T[25:]
# Out:
#                                                                                               0  \
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                   Albany, New York, United States
# neighbourhood_cleansed                                                               SIXTH WARD
# neighbourhood_group_cleansed                                                                NaN
# latitude                                                                               42.65345
# longitude                                                                              -73.7645
# property_type                                                                Entire guest suite
# room_type                                                                       Entire home/apt
# accommodates                                                                                  2
# bathrooms                                                                                   1.0
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        1.0
# amenities                                     ["Microwave", "Iron", "Smoke alarm", "Shower g...
# price                                                                                    $70.00
# minimum_nights                                                                                1
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        1
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      1.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               0
# availability_60                                                                               0
# availability_90                                                                               0
# availability_365                                                                              0
# calendar_last_scraped                                                                11/03/2024
# number_of_reviews                                                                           777
# number_of_reviews_ltm                                                                       131
# number_of_reviews_l30d                                                                        5
# first_review                                                                         09/06/2018
# last_review                                                                          22/02/2024
# review_scores_rating                                                                       4.89
# review_scores_accuracy                                                                     4.93
# review_scores_cleanliness                                                                   4.9
# review_scores_checkin                                                                      4.96
# review_scores_communication                                                                4.95
# review_scores_location                                                                     4.92
# review_scores_value                                                                        4.91
# license                                                                                     NaN
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                         11.08
#
#                                                                                               1  \
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                               NaN
# neighbourhood_cleansed                                                          FOURTEENTH WARD
# neighbourhood_group_cleansed                                                                NaN
# latitude                                                                               42.66078
# longitude                                                                             -73.80553
# property_type                                                                       Entire home
# room_type                                                                       Entire home/apt
# accommodates                                                                                  1
# bathrooms                                                                                   1.0
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        1.0
# amenities                                     ["Microwave", "Iron", "Smoke alarm", "Essentia...
# price                                                                                    $50.00
# minimum_nights                                                                                1
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        1
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      1.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               8
# availability_60                                                                              11
# availability_90                                                                              26
# availability_365                                                                            112
# calendar_last_scraped                                                                11/03/2024
# number_of_reviews                                                                           631
# number_of_reviews_ltm                                                                        98
# number_of_reviews_l30d                                                                        6
# first_review                                                                         05/02/2016
# last_review                                                                          29/02/2024
# review_scores_rating                                                                       4.81
# review_scores_accuracy                                                                     4.88
# review_scores_cleanliness                                                                  4.77
# review_scores_checkin                                                                      4.93
# review_scores_communication                                                                4.87
# review_scores_location                                                                     4.92
# review_scores_value                                                                         4.9
# license                                                                                     NaN
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                2
# calculated_host_listings_count_entire_homes                                                   2
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                           6.4
#
#                                                                                               2  \
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                   Albany, New York, United States
# neighbourhood_cleansed                                                              SECOND WARD
# neighbourhood_group_cleansed                                                                NaN
# latitude                                                                               42.64535
# longitude                                                                             -73.75365
# property_type                                                                       Entire loft
# room_type                                                                       Entire home/apt
# accommodates                                                                                  5
# bathrooms                                                                                   1.0
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        2.0
# amenities                                     ["Microwave", "Iron", "Smoke alarm", "Shower g...
# price                                                                                    $91.00
# minimum_nights                                                                                1
# maximum_nights                                                                               28
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        3
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      2.2
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               0
# availability_60                                                                               0
# availability_90                                                                               0
# availability_365                                                                              0
# calendar_last_scraped                                                                11/03/2024
# number_of_reviews                                                                           616
# number_of_reviews_ltm                                                                        41
# number_of_reviews_l30d                                                                        6
# first_review                                                                         25/11/2018
# last_review                                                                          06/03/2024
# review_scores_rating                                                                        4.8
# review_scores_accuracy                                                                     4.88
# review_scores_cleanliness                                                                  4.84
# review_scores_checkin                                                                      4.86
# review_scores_communication                                                                4.91
# review_scores_location                                                                     4.74
# review_scores_value                                                                        4.82
# license                                                                                     NaN
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                6
# calculated_host_listings_count_entire_homes                                                   6
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          9.56
#
#                                                                                               3  \
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                   Albany, New York, United States
# neighbourhood_cleansed                                                               SIXTH WARD
# neighbourhood_group_cleansed                                                                NaN
# latitude                                                                               42.65559
# longitude                                                                             -73.76506
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                   1.0
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        2.0
# amenities                                     ["Microwave", "Smoke alarm", "Shower gel", "Co...
# price                                                                                    $87.00
# minimum_nights                                                                                1
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        1
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      1.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               0
# availability_60                                                                               0
# availability_90                                                                               0
# availability_365                                                                              0
# calendar_last_scraped                                                                11/03/2024
# number_of_reviews                                                                           580
# number_of_reviews_ltm                                                                        39
# number_of_reviews_l30d                                                                        2
# first_review                                                                         07/08/2016
# last_review                                                                          25/02/2024
# review_scores_rating                                                                       4.79
# review_scores_accuracy                                                                     4.86
# review_scores_cleanliness                                                                  4.83
# review_scores_checkin                                                                      4.95
# review_scores_communication                                                                4.92
# review_scores_location                                                                     4.87
# review_scores_value                                                                        4.78
# license                                                                                     NaN
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          6.27
#
#                                                                                               4
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                   Albany, New York, United States
# neighbourhood_cleansed                                                              SECOND WARD
# neighbourhood_group_cleansed                                                                NaN
# latitude                                                                               42.64535
# longitude                                                                             -73.75365
# property_type                                                                Entire guest suite
# room_type                                                                       Entire home/apt
# accommodates                                                                                  3
# bathrooms                                                                                   1.0
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    0.0
# beds                                                                                        2.0
# amenities                                     ["Microwave", "Iron", "Smoke alarm", "Shower g...
# price                                                                                    $62.00
# minimum_nights                                                                                1
# maximum_nights                                                                               28
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        1
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      1.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                              16
# availability_60                                                                              42
# availability_90                                                                              53
# availability_365                                                                            299
# calendar_last_scraped                                                                11/03/2024
# number_of_reviews                                                                           541
# number_of_reviews_ltm                                                                        76
# number_of_reviews_l30d                                                                        7
# first_review                                                                         14/12/2018
# last_review                                                                          04/03/2024
# review_scores_rating                                                                        4.7
# review_scores_accuracy                                                                     4.76
# review_scores_cleanliness                                                                  4.71
# review_scores_checkin                                                                      4.81
# review_scores_communication                                                                4.89
# review_scores_location                                                                     4.63
# review_scores_value                                                                        4.69
# license                                                                                     NaN
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                6
# calculated_host_listings_count_entire_homes                                                   6
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          8.48

# %%
# check duplicate rows in dataset
df = df.drop_duplicates()
df.count()
# Out:
# id                                              404
# listing_url                                     404
# scrape_id                                       404
# last_scraped                                    404
# source                                          404
#                                                ...
# calculated_host_listings_count                  404
# calculated_host_listings_count_entire_homes     404
# calculated_host_listings_count_private_rooms    404
# calculated_host_listings_count_shared_rooms     404
# reviews_per_month                               362
# Length: 75, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2571

# %%
df['id'].nunique()
# Out:
# 404

# %%
df['host_id'].nunique()
# Out:
# 192

# %% [markdown]
# ##### From the exploration above we discover some facts about this Airbnb Dataset.
# 1. The Data includes both categorical and numeric values.
# 2. There is no any duplicate rows in Dataset.
# 3. There are some columns are not required for our analysis.
# 4. Dataset contains 2571 null values.
# 5. All listings are unique but some of them common between the same host.
# ##### Some actions for make dataset more clear
# 1. Drop unuseful features and observations.
# 2. Feature formate conversion.
# 3. Handeling missing values.
# 4. Handeling outliers.

# %% [markdown]
# #### 1. Drop unuseful features and observations.
# - By making some investigation to dataset features, we will find some features have no output on our analysis, for this we are going to drop them.
# - Droping any observation rather except Albany, NY in host_location column.

# %%
df.describe(include=['bool', 'object']).iloc[:,:20]
# Out:
#                                   listing_url last_scraped       source  \
# count                                     404          404          404
# unique                                    404            2            2
# top     https://www.airbnb.com/rooms/25549565   11/03/2024  city scrape
# freq                                        1          380          350
#
#                                  name  \
# count                             404
# unique                            403
# top     Lovely private room in Albany
# freq                                2
#
#                                               description  \
# count                                                 392
# unique                                                357
# top     Charming 5 room bed and breakfast located acro...
# freq                                                    5
#
#                                     neighborhood_overview  \
# count                                                 245
# unique                                                200
# top     The Argus Hotel is located directly on Washing...
# freq                                                   11
#
#                                               picture_url  \
# count                                                 404
# unique                                                400
# top     https://a0.muscache.com/pictures/miso/Hosting-...
# freq                                                    3
#
#                                            host_url host_name  host_since  \
# count                                           404       404         404
# unique                                          192       175         189
# top     https://www.airbnb.com/users/show/232967878     Diana  28/12/2018
# freq                                             22        25          22
#
#        host_location                                         host_about  \
# count            313                                                214
# unique            21                                                 96
# top       Albany, NY  I have the great honor of being able to invite...
# freq             232                                                 10
#
#        host_response_time host_response_rate host_acceptance_rate  \
# count                 375                375                  389
# unique                  4                 14                   38
# top        within an hour               100%                 100%
# freq                  318                314                   91
#
#        host_is_superhost                                 host_thumbnail_url  \
# count                403                                                404
# unique                 2                                                185
# top                    f  https://a0.muscache.com/im/pictures/user/User-...
# freq                 210                                                 22
#
#                                          host_picture_url host_neighbourhood  \
# count                                                 404                321
# unique                                                185                 31
# top     https://a0.muscache.com/im/pictures/user/User-...         Pine Hills
# freq                                                   22                 65
#
#         host_verifications
# count                  404
# unique                   4
# top     ['email', 'phone']
# freq                   328

# %%
df.describe(include=['bool', 'object']).iloc[:,20:]
# Out:
#        host_has_profile_pic host_identity_verified  \
# count                   404                    404
# unique                    2                      2
# top                       t                      t
# freq                    396                    360
#
#                           neighbourhood neighbourhood_cleansed  \
# count                               245                    404
# unique                                1                     15
# top     Albany, New York, United States             SIXTH WARD
# freq                                245                     88
#
#              property_type        room_type bathrooms_text  \
# count                  404              404            404
# unique                  20                3             17
# top     Entire rental unit  Entire home/apt         1 bath
# freq                   198              287            247
#
#                                                 amenities    price  \
# count                                                 404      350
# unique                                                399      121
# top     ["Microwave", "Iron", "Smoke alarm", "Shower g...  $100.00
# freq                                                    2       16
#
#        has_availability calendar_last_scraped first_review last_review  \
# count               399                   404          362         362
# unique                1                     2          305         159
# top                   t            11/03/2024   01/01/2023  25/02/2024
# freq                399                   380            4          20
#
#        instant_bookable
# count               404
# unique                2
# top                   f
# freq                310

# %%
df.describe().iloc[:,:20]
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  4.040000e+02  4.040000e+02  4.040000e+02           404.000000
# mean   5.075502e+17  2.024030e+13  2.215851e+08            22.613861
# std    4.254315e+17  0.000000e+00  1.796507e+08           137.436182
# min    1.489424e+06  2.024030e+13  6.490680e+05             1.000000
# 25%    4.662195e+07  2.024030e+13  4.762598e+07             2.000000
# 50%    6.686083e+17  2.024030e+13  1.870609e+08             4.000000
# 75%    9.022064e+17  2.024030e+13  3.872668e+08             8.000000
# max    1.104977e+18  2.024030e+13  5.531120e+08          1177.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed    latitude  \
# count                 404.000000                           0.0  404.000000
# mean                   38.175743                           NaN   42.657382
# std                   243.984768                           NaN    0.009623
# min                     1.000000                           NaN   42.630660
# 25%                     2.000000                           NaN   42.651845
# 50%                     5.000000                           NaN   42.657168
# 75%                    13.000000                           NaN   42.662161
# max                  2118.000000                           NaN   42.714896
#
#         longitude  accommodates   bathrooms    bedrooms        beds  \
# count  404.000000    404.000000  350.000000  400.000000  350.000000
# mean   -73.776875      3.522277    1.211429    1.620000    1.748571
# std      0.019607      2.493067    0.618146    1.035994    1.208701
# min    -73.876489      1.000000    0.000000    0.000000    0.000000
# 25%    -73.790344      2.000000    1.000000    1.000000    1.000000
# 50%    -73.773448      3.000000    1.000000    1.000000    1.000000
# 75%    -73.761915      4.000000    1.000000    2.000000    2.000000
# max    -73.738103     16.000000    7.000000    7.000000    8.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count      404.000000      404.000000              404.000000
# mean         5.222772      538.388614                5.086634
# std         21.515183      439.154189               21.486216
# min          1.000000        1.000000                1.000000
# 25%          1.000000      126.250000                1.000000
# 50%          2.000000      365.000000                2.000000
# 75%          3.000000     1125.000000                3.000000
# max        365.000000     1125.000000              365.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count               404.00000              404.000000              404.000000
# mean                  5.60396              762.363861              785.210396
# std                  21.64183              447.466853              438.579291
# min                   1.00000                1.000000                1.000000
# 25%                   1.00000              365.000000              365.000000
# 50%                   2.00000             1125.000000             1125.000000
# 75%                   3.00000             1125.000000             1125.000000
# max                 365.00000             1125.000000             1125.000000
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm
# count              404.000000              404.000000
# mean                 5.266337              780.669059
# std                 21.480950              436.704312
# min                  1.000000                1.000000
# 25%                  1.000000              365.000000
# 50%                  2.000000             1125.000000
# 75%                  3.000000             1125.000000
# max                365.000000             1125.000000

# %%
df.describe().iloc[:,20:]
# Out:
#        calendar_updated  availability_30  availability_60  availability_90  \
# count               0.0       404.000000       404.000000       404.000000
# mean                NaN        14.324257        32.564356        51.866337
# std                 NaN        11.817315        23.493589        34.432470
# min                 NaN         0.000000         0.000000         0.000000
# 25%                 NaN         0.000000         1.000000        12.000000
# 50%                 NaN        15.000000        39.000000        64.000000
# 75%                 NaN        26.000000        54.000000        83.000000
# max                 NaN        30.000000        60.000000        90.000000
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# count        404.000000         404.000000             404.000000
# mean         202.027228          54.732673              16.022277
# std          131.345837          98.541437              21.572016
# min            0.000000           0.000000               0.000000
# 25%           79.000000           4.000000               1.000000
# 50%          244.000000          16.000000               7.000000
# 75%          327.250000          61.000000              22.000000
# max          365.000000         777.000000             131.000000
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# count              404.000000            362.000000              362.000000
# mean                 1.205446              4.793729                4.828978
# std                  1.835646              0.283063                0.273238
# min                  0.000000              3.000000                3.000000
# 25%                  0.000000              4.720000                4.800000
# 50%                  0.000000              4.880000                4.910000
# 75%                  2.000000              4.990000                5.000000
# max                  8.000000              5.000000                5.000000
#
#        ...  review_scores_checkin  review_scores_communication  \
# count  ...             362.000000                   362.000000
# mean   ...               4.871298                     4.875856
# std    ...               0.220687                     0.250180
# min    ...               3.000000                     2.670000
# 25%    ...               4.830000                     4.852500
# 50%    ...               4.950000                     4.960000
# 75%    ...               5.000000                     5.000000
# max    ...               5.000000                     5.000000
#
#        review_scores_location  review_scores_value  license  \
# count              362.000000           362.000000      0.0
# mean                 4.710166             4.751243      NaN
# std                  0.328145             0.297942      NaN
# min                  3.000000             3.000000      NaN
# 25%                  4.582500             4.670000      NaN
# 50%                  4.820000             4.820000      NaN
# 75%                  4.950000             4.940000      NaN
# max                  5.000000             5.000000      NaN
#
#        calculated_host_listings_count  \
# count                      404.000000
# mean                         5.133663
# std                          5.436021
# min                          1.000000
# 25%                          1.000000
# 50%                          3.000000
# 75%                          6.500000
# max                         22.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                   404.000000
# mean                                      3.769802
# std                                       5.534819
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       4.000000
# max                                      22.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                    404.000000
# mean                                       1.358911
# std                                        2.623126
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.250000
# max                                       11.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                   404.000000         362.000000
# mean                                      0.004950           1.992403
# std                                       0.070272           1.957821
# min                                       0.000000           0.050000
# 25%                                       0.000000           0.510000
# 50%                                       0.000000           1.370000
# 75%                                       0.000000           2.760000
# max                                       1.000000          11.080000
#
# [8 rows x 21 columns]

# %%
list_of_droped_features = ['host_response_rate', 'bathrooms_text', 'bathrooms','host_acceptance_rate','number_of_reviews_ltm', 'number_of_reviews_l30d',
            'first_review', 'last_review','calculated_host_listings_count_entire_homes','neighbourhood_cleansed'
             , 'calculated_host_listings_count_private_rooms', 'host_response_time','neighbourhood','license'
            ,'calculated_host_listings_count_shared_rooms','host_since', 'minimum_minimum_nights', 'maximum_minimum_nights', 
            'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 
            'host_is_superhost', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified','amenities',
            'instant_bookable','host_total_listings_count','has_availability', 'listing_url', 'scrape_id','last_scraped',
            'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name',
            'host_picture_url',	'host_neighbourhood', 'host_listings_count','host_about','host_thumbnail_url',
            'neighbourhood_group_cleansed', 'latitude', 'longitude', 'calendar_updated', 'calendar_last_scraped']

# %%
df.drop(list_of_droped_features, axis=1, inplace=True)

# %%
# Our dataset contains 19 listings that have never been reviewed, we will drop them because we need the reviewd listings in our analysis.
print(df['number_of_reviews'].value_counts(ascending=False).head(1))
# Out:
# number_of_reviews
# 0    42
# Name: count, dtype: int64

# %%
df=df.sort_values(by='number_of_reviews')
df.drop(df.index[:42], inplace=True)

# %%
# We can custimize related features in one feature, by taking the average of all reviews.
new_features = df[['review_scores_rating','review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
                   'review_scores_communication','review_scores_location','review_scores_value']]
df['avg_review_scores'] = new_features.sum(axis=1)/len(new_features.columns)
df.drop(new_features, axis=1, inplace=True)
df['avg_review_scores'].sample(3)
# Out:
# 232    4.704286
# 62     4.922857
# 258    4.940000
# Name: avg_review_scores, dtype: float64

# %% [markdown]
# #### 2. Feature formate conversion.

# %%
df['price']=df['price'].replace('[/$,]', '',regex=True).astype('float')

# %% [markdown]
# #### 3. Handeling missing values.

# %%
#from previous investigation we see that the most frequent value is 'Albany, NY' by about 75% out of all values.
#for this, I will handel all missing values in this feature by this value.
df.fillna({'host_location':df['host_location'].mode()[0]}, inplace=True)

# %%
list_1 = list(df[df.host_location != 'Albany, NY'].index)
df = df.drop(list_1)

# %%
df.drop('host_location', axis=1, inplace=True)

# %% [markdown]
# There missing values in the following features('bedrooms','beds','price'), we are going to do some analysis to fill these missing values.

# %%
def group_by_dict(data,col_1, col_2):
    '''this fuanction takes three arguments, datafram and two columns 
    returning dictionary(keys = unique values of col_1, values = median of col_2 grouped by unique values of col_1)'''
    return dict(data.groupby(col_1)[col_2].median())

# %%
acc_room = group_by_dict(df,'accommodates', 'bedrooms')
acc_bed = group_by_dict(df,'accommodates', 'beds')
acc_price = group_by_dict(df,'accommodates', 'price')
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(20,5))
ax1.plot(acc_room.keys(), acc_room.values())
ax2.plot(acc_bed.keys(), acc_bed.values())
ax3.plot(acc_price.keys(), acc_price.values())
# From this analysis, we found taht all three features(accommodates,beds,price)  related to bedrooms with some exceptions but 
# we can find some pattern to fillna in all three features by using this analysis.
# First: start with filling NaN of returned dictionary from group_by_dict() function.
# second : filling NaN of these datafram's features.

# %% [markdown]
# Because we have just one NaN in each acc_bed and acc_price dicts, we will handel it by simple function, this function fillna by taking the average (2 higher values ​​+ 2 lower values).

# %%
def fill_dict_na(dict_):
    def fill_accommodates_nan(row):
        k, v = row
        if np.isnan(v):
            a = [dict_.get(k-1) , dict_.get(k-2) , dict_.get(k+1) , dict_.get(k+2)]
            a_1 = sum(a)/len(a)
            if a_1%1 < 0.5/2:
                a_1 = float(int(a_1))
            elif a_1%1 <= 0.5:
                a_1 = int(a_1)+0.5
            elif a_1%1 < (0.5+0.5/2):
                a_1 = int(a_1)+.5  
            else:
                a_1 = round(a_1)
            row = k, a_1
        return row
    return dict(map(fill_accommodates_nan, dict_.items()))

# %%
acc_bed = fill_dict_na(acc_bed)
acc_price = fill_dict_na(acc_price)
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(20,5))
ax1.plot(acc_room.keys(), acc_room.values())
ax2.plot(acc_bed.keys(), acc_bed.values())
ax3.plot(acc_price.keys(), acc_price.values())
plt.yscale("log")

# %%
def replace_price_nan_value(row, col_n, dict_):
    if np.isnan(row[col_n]):
        row[col_n] = dict_[row["accommodates"]]
    # print("Done!")
    return row

# %%
df = df.apply(functools.partial(replace_price_nan_value, col_n = 'bedrooms', dict_=acc_room), axis = 1)
df = df.apply(functools.partial(replace_price_nan_value, col_n = 'beds', dict_=acc_bed), axis = 1)
df = df.apply(functools.partial(replace_price_nan_value, col_n = 'price', dict_=acc_price), axis = 1)

# %% [markdown]
# #### Now, The data is cleared with no missing values, ready for analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 287 entries, 351 to 0
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              287 non-null    int64
#  1   host_id                         287 non-null    int64
#  2   property_type                   287 non-null    object
#  3   room_type                       287 non-null    object
#  4   accommodates                    287 non-null    int64
#  5   bedrooms                        287 non-null    float64
#  6   beds                            287 non-null    float64
#  7   price                           287 non-null    float64
#  8   minimum_nights                  287 non-null    int64
#  9   maximum_nights                  287 non-null    int64
#  10  availability_30                 287 non-null    int64
#  11  availability_60                 287 non-null    int64
#  12  availability_90                 287 non-null    int64
#  13  availability_365                287 non-null    int64
#  14  number_of_reviews               287 non-null    int64
#  15  calculated_host_listings_count  287 non-null    int64
#  16  reviews_per_month               287 non-null    float64
#  17  avg_review_scores               287 non-null    float64
# dtypes: float64(5), int64(11), object(2)
# memory usage: 42.6+ KB

# %% [markdown]
# 4. Handeling outliers.

# %%
room_acc = group_by_dict(df,'bedrooms', 'accommodates')
room_bed = group_by_dict(df,'bedrooms', 'beds')
room_price = group_by_dict(df,'bedrooms', 'price')
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(20,5))
ax1.plot(room_acc.keys(), room_acc.values())
ax2.plot(room_bed.keys(), room_bed.values())
ax3.plot(room_price.keys(), room_price.values())

# %% [markdown]
# There are no outliers that could be influence our analysis, and the large and small values match the same in the correspond influenced feature.

# %% [markdown]
# ###
# 1. h
# 2. h
# 3. h
# 4. h
# 5. h
# 6. h
# 7. h
# 8. h
# 9. h

# %% [markdown]
# # Data Visualization giving insights for demand.

# %% [markdown]
# 1. Distribution Of Airbnb Bookings Price Range Using Histogram

# %%
# Declare c_l variable.
c_l = df.columns
# Create a figure with a custom size
plt.figure(figsize=(12, 5))

# Set the seaborn theme to darkgrid
sns.set_theme(style='darkgrid')

# Create a histogram of the 'price' column of the df dataframe
# using sns distplot function and specifying the color as red
sns.distplot(df['price'],color=('r'))

# Add labels to the x-axis and y-axis
plt.xlabel('Price', fontsize=14)
plt.ylabel('Density', fontsize=14)

# Add a title to the plot
plt.title('Distribution of Airbnb Prices',fontsize=15)
df['price'].describe()
# Out:
# /var/folders/r9/013lqpnn2cj0hh05j71mb64h0000gn/T/ipykernel_34487/2189793841.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],color=('r'))
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    287.000000
# mean     114.386760
# std       62.066921
# min       26.000000
# 25%       78.000000
# 50%      101.000000
# 75%      129.500000
# max      570.000000
# Name: price, dtype: float64

# %% [markdown]
# observations -->
#
# The range of prices being charged on Airbnb appears to be from 26 to 628 dollars , with the majority of listings falling in the price range of 50 to 150 dollars(high demand).
#
# The distribution of prices appears to have a peak in the 50 to 150 dollars range, with a relatively lower density of listings in higher and lower price ranges.
#
# There may be fewer listings available at prices above 250 dollars(low demand), as the density of listings drops significantly in this range.

# %% [markdown]
# 2. Total Listing/Property count in Each property_type and room_type using Count plot.

# %%
# Set the figure size
plt.figure(figsize=(12, 8))

# Create a countplot of the property_type data
my_plot = sns.countplot(x="property_type", data=df)
# Set the title of the plot
plt.title('property_type Listing Counts in Albany', fontsize=15)

# Set the x-axis label
plt.xlabel('property_type', fontsize=14)

# Set the y-axis label
plt.ylabel('total listings counts', fontsize=14)

my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=90)
df['property_type'].value_counts(normalize=True)
# Out:
# property_type
# Entire rental unit             0.512195
# Private room in home           0.174216
# Entire home                    0.156794
# Private room in rental unit    0.038328
# Entire townhouse               0.020906
# Room in hotel                  0.017422
# Private room in townhouse      0.013937
# Entire guest suite             0.013937
# Entire vacation home           0.010453
# Entire serviced apartment      0.006969
# Entire condo                   0.006969
# Entire loft                    0.006969
# Private room in guest suite    0.006969
# Entire place                   0.003484
# Entire cottage                 0.003484
# Entire guesthouse              0.003484
# Room in aparthotel             0.003484
# Name: proportion, dtype: float64

# %%
_, axes = plt.subplots(nrows=1, ncols=1, figsize=(20,5))
my_plot=sns.countplot(x=df['property_type'], hue=df['room_type'])
my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=90)

pd.crosstab(df['property_type'],df['room_type'], normalize=True)
# Out:
# room_type                    Entire home/apt  Private room
# property_type
# Entire condo                        0.006969      0.000000
# Entire cottage                      0.003484      0.000000
# Entire guest suite                  0.013937      0.000000
# Entire guesthouse                   0.003484      0.000000
# Entire home                         0.156794      0.000000
# Entire loft                         0.006969      0.000000
# Entire place                        0.003484      0.000000
# Entire rental unit                  0.512195      0.000000
# Entire serviced apartment           0.006969      0.000000
# Entire townhouse                    0.020906      0.000000
# Entire vacation home                0.010453      0.000000
# Private room in guest suite         0.000000      0.006969
# Private room in home                0.000000      0.174216
# Private room in rental unit         0.000000      0.038328
# Private room in townhouse           0.000000      0.013937
# Room in aparthotel                  0.003484      0.000000
# Room in hotel                       0.000000      0.017422

# %%
# Set the figure size
plt.figure(figsize=(12, 8))

# Create a countplot of the room_type data
my_plot = sns.countplot(x="room_type", data=df)
# Set the title of the plot
plt.title('room_type Listing Counts in Albany', fontsize=15)

# Set the x-axis label
plt.xlabel('room_type', fontsize=14)

# Set the y-axis label
plt.ylabel('total listings counts', fontsize=14)

my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=90)
df['room_type'].value_counts(normalize=True)
# Out:
# room_type
# Entire home/apt    0.749129
# Private room       0.250871
# Name: proportion, dtype: float64

# %% [markdown]
# Observations -->
#
# - First: the highest property_type in demand are Entire rental unit, Private room in home and Entire home with these presentages 51%, 17.5%, 15.5% respectively.
# - Second: The room type demand at Albany city are for Entire home/apt and Private room with these precentages 75%, 25% respectively.

# %% [markdown]
# 3. Average Price Of Each unique value of accommodates using Point Plot.

# %%
#import mean function from the statistics module 
from statistics import mean

# Create the point plot
sns.pointplot(x = 'accommodates', y='price', data=df, estimator = np.mean)

# Add axis labels and a title
plt.xlabel('no of accommodates',fontsize=14)
plt.ylabel('Average Price',fontsize=14)
plt.title('Average Price by no of accommodates',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Average Price by no of accommodates')

# %% [markdown]
# Observations --> price increases as no of accommodates increases.

# %% [markdown]
# 4. Price Distribution Of Each on of bedrooms using Violin Plot.

# %%
# Create the violin plot for price distribution in each property_type  
ax=sns.violinplot(x='bedrooms',y='price',data= df)

# %% [markdown]
# Observations -->
#
# As number of bedrooms increase the price and price distribution increase.

# %% [markdown]
# 5. Top number of bedrooms by Listing/property using Bar plot

# %%
# Create a list of colors to use for the bars
colors = ['c', 'g', 'olive', 'y', 'm', 'orange']

# Create a bar plot of no of bedrooms using the specified colors
df['bedrooms'].value_counts().plot(kind='bar', figsize=(15, 6), color = colors)

# Set the x-axis label
plt.xlabel('no of bedrooms', fontsize=14)

# Set the y-axis label
plt.ylabel('Total Listing Counts', fontsize=14)

# Set the title of the plot
plt.title('Listings by no of bedrooms in Albany', fontsize=15)
df['bedrooms'].value_counts(normalize=True)
# Out:
# bedrooms
# 1.0    0.592334
# 2.0    0.209059
# 3.0    0.090592
# 4.0    0.048780
# 0.0    0.038328
# 5.0    0.020906
# Name: proportion, dtype: float64

# %% [markdown]
# Observations -->
#
# In terms of number of bedrooms, the most demanding is one and two bedrooms with 60% and 20% respectively.
# As number of bedrooms increases the demand decreases.

# %% [markdown]
# 6. Total Listing/Property count by number of accommodates using Bar chart.

# %%
# Create a bar plot of the number of accommodates
df['accommodates'].value_counts().plot(kind='bar', color='peru', figsize=(18, 7))

# Set the x-axis label
plt.xlabel('number of accommodates', fontsize=14)

# Set the y-axis label
plt.ylabel('total_Albany_listings', fontsize=14)

# Set the title of the plot
plt.title('no of listings by number of accommodate in Albany!', fontsize=15)
df['accommodates'].value_counts(normalize=True)
# Out:
# accommodates
# 2     0.383275
# 4     0.195122
# 1     0.108014
# 3     0.101045
# 6     0.076655
# 5     0.041812
# 8     0.024390
# 7     0.024390
# 10    0.017422
# 12    0.010453
# 15    0.003484
# 14    0.003484
# 11    0.003484
# 13    0.003484
# 9     0.003484
# Name: proportion, dtype: float64

# %% [markdown]
# Observations -->
#
# The highest demanding number of accommodates are 2, 4, 1, 3 with 38%, 19%, 10%, 10% respectively.
# The lowest demanding number of accommodates from nine to above.

# %% [markdown]
# 7. Total Listing/Property count by number of beds using pie plot.

# %%
# Create a pie plot of the number of beds
df['beds'].value_counts().plot(kind='pie',figsize=(10, 5))

# Set the title of the plot
plt.title('no of listings by number of beds in Albany!', fontsize=15)
df['beds'].value_counts(normalize=True)
# Out:
# beds
# 1.0    0.505226
# 2.0    0.278746
# 3.0    0.094077
# 4.0    0.052265
# 0.0    0.027875
# 5.0    0.024390
# 6.0    0.013937
# 7.0    0.003484
# Name: proportion, dtype: float64

# %% [markdown]
# Observations -->
#
# The highest demanding number of beds are 1, 2 with 50%, 28% respectively. The lowest demanding number of beds from five to above including zero no of beds.

# %%
# make new feature using availability_365 to categorize availability
import math
def check_av(value):
    if value == 0:
        return "no_av"
    elif value <= 30:
        days = math.ceil(value/10)*10
        return f"av_{days}"
    elif value <= 330:
        days = math.ceil(value/30)*30
        return f"av_{days}"
    else:
        return "av_all _the _year"

# %%
df['av_cat']= df['availability_365'].apply(check_av)

# %% [markdown]
#     8. Analysis using new  availability categories feature.

# %%
# Create a list of colors to use for the bars
colors = ['c', 'g', 'olive', 'y', 'm', 'orange', '#C0C0C0', '#800000', '#008000', '#000080']

# Create a bar plot of availability categories using the specified colors
df['av_cat'].value_counts().plot(kind='bar', figsize=(15, 6), color = colors)

# Set the x-axis label
plt.xlabel('availability categories', fontsize=14)

# Set the y-axis label
plt.ylabel('Total Listing Counts', fontsize=14)

# Set the title of the plot
plt.title('Listings by availability categories in Albany', fontsize=15)
df['av_cat'].value_counts(normalize=True)
# Out:
# av_cat
# av_all _the _year    0.257840
# no_av                0.209059
# av_270               0.090592
# av_180               0.080139
# av_300               0.073171
# av_90                0.062718
# av_330               0.052265
# av_240               0.048780
# av_150               0.027875
# av_60                0.024390
# av_120               0.024390
# av_210               0.020906
# av_20                0.010453
# av_10                0.010453
# av_30                0.006969
# Name: proportion, dtype: float64

# %% [markdown]
# Observations -->
#
# av_all _the _year and no_av are the most dominant, we can make more deep analysis to make this new feature more informable.

# %%
_, axes = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(20,10))
sns.countplot(x='av_cat', hue=df['room_type'].astype('str'), data=df, ax=axes)
#sns.countplot(x='Voice mail plan', hue=df['Churn'].astype('str'), data=df, ax=axes[1])
pd.crosstab(df['av_cat'], df['room_type'], normalize=True)
# Out:
# room_type          Entire home/apt  Private room
# av_cat
# av_10                     0.006969      0.003484
# av_120                    0.013937      0.010453
# av_150                    0.020906      0.006969
# av_180                    0.048780      0.031359
# av_20                     0.010453      0.000000
# av_210                    0.017422      0.003484
# av_240                    0.038328      0.010453
# av_270                    0.076655      0.013937
# av_30                     0.003484      0.003484
# av_300                    0.048780      0.024390
# av_330                    0.027875      0.024390
# av_60                     0.020906      0.003484
# av_90                     0.048780      0.013937
# av_all _the _year         0.198606      0.059233
# no_av                     0.167247      0.041812

# %%
plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(20,10))
plt.bar(dict(df.groupby('av_cat')['price'].agg(np.mean)).keys(), dict(df.groupby('av_cat')['price'].agg(np.mean)).values(),width=0.5,color='r')
plt.xlabel('Availability')
plt.ylabel('Average Price')
plt.title('Average Price & Availability')

# Show the plot
plt.show()
# Out:
# /var/folders/r9/013lqpnn2cj0hh05j71mb64h0000gn/T/ipykernel_34487/4112399284.py:2: FutureWarning: The provided callable <function mean at 0x111637ba0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   plt.bar(dict(df.groupby('av_cat')['price'].agg(np.mean)).keys(), dict(df.groupby('av_cat')['price'].agg(np.mean)).values(),width=0.5,color='r')
# /var/folders/r9/013lqpnn2cj0hh05j71mb64h0000gn/T/ipykernel_34487/4112399284.py:2: FutureWarning: The provided callable <function mean at 0x111637ba0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   plt.bar(dict(df.groupby('av_cat')['price'].agg(np.mean)).keys(), dict(df.groupby('av_cat')['price'].agg(np.mean)).values(),width=0.5,color='r')

# %% [markdown]
# Observations -->
#
# No such pattern here but we will go to another one, but we can see that Entire home/apt has high demand.

# %% [markdown]
# 9. Correlation Heatmap Visualization

# %%
# Calculate pairwise correlations between columns
# Drop non-numerical variables
plt.figure(figsize=(20,10))
numerical = list(
    set(df.columns)
    - {
        "id",
        "host_id",
        "property_type",
        "room_type",
        "av_cat",
    }
)
# Calculate pairwise correlations between columns
corr = df[numerical].corr()

# Display the correlation between columns
corr
# Out:
#                                 availability_365  reviews_per_month  \
# availability_365                        1.000000          -0.229118
# reviews_per_month                      -0.229118           1.000000
# avg_review_scores                      -0.089144           0.156081
# number_of_reviews                      -0.148224           0.709907
# maximum_nights                          0.182008          -0.002942
# availability_30                         0.577492          -0.177091
# calculated_host_listings_count         -0.077836          -0.072648
# bedrooms                               -0.044051          -0.014590
# beds                                   -0.051439           0.111063
# minimum_nights                          0.088984          -0.080085
# availability_60                         0.662617          -0.188001
# accommodates                           -0.060876           0.099114
# price                                   0.006873          -0.036364
# availability_90                         0.706650          -0.213216
#
#                                 avg_review_scores  number_of_reviews  \
# availability_365                        -0.089144          -0.148224
# reviews_per_month                        0.156081           0.709907
# avg_review_scores                        1.000000           0.089193
# number_of_reviews                        0.089193           1.000000
# maximum_nights                           0.030948           0.159173
# availability_30                          0.035069          -0.141383
# calculated_host_listings_count          -0.033369          -0.072503
# bedrooms                                 0.029089          -0.174178
# beds                                     0.092384          -0.006031
# minimum_nights                          -0.046240          -0.055108
# availability_60                         -0.018273          -0.140325
# accommodates                             0.098788          -0.039095
# price                                    0.091647          -0.121278
# availability_90                         -0.019970          -0.155793
#
#                                 maximum_nights  availability_30  \
# availability_365                      0.182008         0.577492
# reviews_per_month                    -0.002942        -0.177091
# avg_review_scores                     0.030948         0.035069
# number_of_reviews                     0.159173        -0.141383
# maximum_nights                        1.000000         0.000493
# availability_30                       0.000493         1.000000
# calculated_host_listings_count        0.126210         0.071484
# bedrooms                             -0.029023        -0.018507
# beds                                  0.027986        -0.021190
# minimum_nights                       -0.036485         0.047894
# availability_60                       0.003847         0.948641
# accommodates                         -0.027304        -0.031969
# price                                 0.004241         0.097404
# availability_90                       0.022360         0.898962
#
#                                 calculated_host_listings_count  bedrooms  \
# availability_365                                     -0.077836 -0.044051
# reviews_per_month                                    -0.072648 -0.014590
# avg_review_scores                                    -0.033369  0.029089
# number_of_reviews                                    -0.072503 -0.174178
# maximum_nights                                        0.126210 -0.029023
# availability_30                                       0.071484 -0.018507
# calculated_host_listings_count                        1.000000  0.070588
# bedrooms                                              0.070588  1.000000
# beds                                                  0.054857  0.774464
# minimum_nights                                       -0.047229 -0.053763
# availability_60                                       0.040142 -0.017050
# accommodates                                          0.092504  0.844249
# price                                                 0.214705  0.633030
# availability_90                                       0.009604 -0.036839
#
#                                     beds  minimum_nights  availability_60  \
# availability_365               -0.051439        0.088984         0.662617
# reviews_per_month               0.111063       -0.080085        -0.188001
# avg_review_scores               0.092384       -0.046240        -0.018273
# number_of_reviews              -0.006031       -0.055108        -0.140325
# maximum_nights                  0.027986       -0.036485         0.003847
# availability_30                -0.021190        0.047894         0.948641
# calculated_host_listings_count  0.054857       -0.047229         0.040142
# bedrooms                        0.774464       -0.053763        -0.017050
# beds                            1.000000       -0.060126        -0.022967
# minimum_nights                 -0.060126        1.000000         0.053875
# availability_60                -0.022967        0.053875         1.000000
# accommodates                    0.851178       -0.070655        -0.036297
# price                           0.688421       -0.062422         0.067498
# availability_90                -0.048571        0.055848         0.974131
#
#                                 accommodates     price  availability_90
# availability_365                   -0.060876  0.006873         0.706650
# reviews_per_month                   0.099114 -0.036364        -0.213216
# avg_review_scores                   0.098788  0.091647        -0.019970
# number_of_reviews                  -0.039095 -0.121278        -0.155793
# maximum_nights                     -0.027304  0.004241         0.022360
# availability_30                    -0.031969  0.097404         0.898962
# calculated_host_listings_count      0.092504  0.214705         0.009604
# bedrooms                            0.844249  0.633030        -0.036839
# beds                                0.851178  0.688421        -0.048571
# minimum_nights                     -0.070655 -0.062422         0.055848
# availability_60                    -0.036297  0.067498         0.974131
# accommodates                        1.000000  0.751074        -0.065264
# price                               0.751074  1.000000         0.025964
# availability_90                    -0.065264  0.025964         1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df[numerical].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Observations -->
#
# Price, accommodates, bedrooms and beds features are strong coorrelated and drive the business in Albany city.

# %% [markdown]
# 10. Pair Plot Visualization

# %%
# create a pairplot using the seaborn library to visualize the relationships between different variables in the Airbnb Albany dataset
sns.pairplot(df)

# show the plot
plt.show()
# Out:
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/drmorsy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# - A pair plot consists of multiple scatterplots arranged in a grid, with each scatterplot showing the relationship between two variables
#
# - It can be used to visualize relationships between multiple variables and to identify patterns in the data.

# %% [markdown]
# BUSINESS CONCLUSION :-
#
# - Price, accommodates, bedrooms and beds features are strong coorrelated and drive the business in Albany city.
# - Demand for Airbnb rentals in Albany city influenced by these group of features (Price, accommodates, bedrooms, beds, property_type and room_type).
#
# Observations -->
# 1. Price:
# - The range of prices being charged on Airbnb rentals in Albany city appears to be from 26 to 628 dollars , with the majority of listings falling in the price range of 50 to 150 dollars(highest demand).
# - The distribution of prices appears to have a peak in the 50 to 150 dollars range, with a relatively lower density of listings in higher and lower price ranges.
# - There may be fewer listings available at prices above 250 dollars(lowest demand), as the density of listings drops significantly in this range.
#
# 2. No of beds:
# - The highest demanding number of beds are 1, 2 with 50%, 28% respectively. The lowest demanding number of beds from five to above including zero no of beds.
#
# 3. No of accommodates:
# - The highest demanding number of accommodates are 2, 4, 1, 3 with 38%, 19%, 10%, 10% respectively. The lowest demanding number of accommodates from nine to above.
#
# 4. No of bedrooms:
# - In terms of number of bedrooms, the most demanding is one and two bedrooms with 60% and 20% respectively.
# - As number of bedrooms increases the demand decreases.
#
# 5. Price & No of accommodates:
# - price increases as no of accommodates increases.
#
# 6. property_type:
# - The highest property_type in demand are Entire rental unit, Private room in home and Entire home with 51%, 17.5%, 15.5% respectively.
#
# 6. room_type:
# - The room_type demand at Albany city are: Entire home/apt with 75% Private room  with 25%.
#
# 7. room_type & property_type:
# - The highest demand property_type in Entire home/apt room_type are: Entire rental unit and Entire home with 51% and 15% respectively of all data.
# - The highest demand property_type in Private room room_type are: Private room in home with 17% of all data.
#
# Insights -->
#
# 1. Listings falling in the price range of 50 to 150 dollars(highest demand) more attractive for investment.
# 2. Precentage of 1 & 2 No of beds have high demand with significant value, and according to this analysis, the larg No of beds decreases the demand and if you go to invist in Albany city 1 or 2 No of beds are best choice.
# 3. There strong demand for Airbnb rentals in Albany city for 2, 4, 1 and 3 No of accommodates that what any investiment have to go with.
# 4. Listing with one bedroom match 60% of demand.
# 5. Listing with larg No of accommodates is more lucrative.
# 6. the most appropriate listing property_type for investment is Entire rental unit.

# %% [markdown]
# #   Thank You
